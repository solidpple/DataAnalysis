# %%
# dataset 불러오기
import pandas as pd
import numpy as np
import matplotlib as plt
# jupyter에서 matplotlib의 결과를 아래 바로 보이게 하기 위해 %matplotlib inline을 입력합니다.
# %matplotlib inline

# 다운로드 받은 데이터를 pandas의 dataframe형태로 읽어옵니다.
df = pd.read_csv("/media/ssd/projects/python/Aries/DataGenerator/power.csv")

# %%
df.head(10)
# Out:
#    total_power  mobile_tx_packets                 package_name  cached  \
# 0   368.148251                  0                            0       0
# 1   244.529712                  0                            0       0
# 2   146.674148              10961               com.kakao.talk       0
# 3   104.183923                  2      android.uid.system:1000       0
# 4    82.481634                828                            0       0
# 5    66.129449               4747          com.facebook.katana       0
# 6    64.656335               1524  com.google.uid.shared:10009       0
# 7    62.210709                  0                            0       0
# 8    52.653254                  0                        99031       0
# 9    25.871967               7346           com.android.chrome       0
#
#    wifi_rx_packets  total_wifi_tx_packets  usage_power_mah  mobile_rx_packets  \
# 0                0                      0       368.148251                  0
# 1                0                      0       244.529712                  0
# 2               86                     81         0.000000              10059
# 3                0                     81         0.000000                  2
# 4               79                    127         0.000000               1372
# 5               54                    174         0.000000               6484
# 6              166                    360         0.000000               1256
# 7                0                    360         0.000000                  0
# 8                0                    360         0.000000                  0
# 9                0                    360         0.000000               7792
#
#    total_mobile_rx_packets  total_wifi_rx_packets  memfree  \
# 0                        0                      0        0
# 1                        0                      0        0
# 2                    10059                     86        0
# 3                    10061                     86        0
# 4                    11433                    165        0
# 5                    17917                    219        0
# 6                    19173                    385        0
# 7                    19173                    385        0
# 8                    19173                    385        0
# 9                    26965                    385        0
#
#    total_mobile_tx_packets  cpu_power_mah  wifi_tx_packets   sum_power  \
# 0                        0       0.000000                0  368.148251
# 1                        0       0.000000                0  244.529712
# 2                    10961      25.247338               81  146.674148
# 3                    10963     101.793066                0  104.183923
# 4                    11791      51.255374               46   82.481634
# 5                    16538       3.710839               47   66.129449
# 6                    18062       7.074114              186   64.656335
# 7                    18062       0.000000                0   62.210709
# 8                    18062      52.653254                0   52.653254
# 9                    25408       9.865977                0   25.871967
#
#    wakelock_power_mah
# 0            0.000000
# 1            0.000000
# 2            2.330854
# 3            1.423576
# 4           15.183516
# 5            0.063086
# 6            2.504727
# 7            0.000000
# 8            0.000000
# 9            0.021428

# %%
df[['memfree','cached','total_mobile_tx_packets','total_mobile_rx_packets','total_wifi_rx_packets','total_wifi_tx_packets']].plot(figsize=(20,10))

# %%
df[df['wifi_rx_packets']!=0]['wifi_rx_packets'].plot()

# %%
package_df = df.groupby('package_name').sum()
package_df.head(10)
# Out:
#                 total_power  mobile_tx_packets      cached  wifi_rx_packets  \
# package_name
# 0             772953.355219             981978  5528250748           467219
# 1006              10.026885                  0   698783716                0
# 1013           15110.994649                  0   698783716                0
# 1014               1.794205                  0   698783716                0
# 1017               3.519066                  0   698783716                0
# 1021             161.183840                  0   698783716                0
# 1023              14.894356                  0   698783716                0
# 1036            2587.667362                  0   698783716                0
# 3005             183.428234                  0   698783716                0
# 3011             261.144224                  0   698783716                0
#
#               usage_power_mah  mobile_rx_packets     memfree  cpu_power_mah  \
# package_name
# 0               635035.733558            1653518  1290061720   54239.393091
# 1006                 0.000000                  0   163975848      10.026885
# 1013                 0.000000                  0   163975848   14212.999466
# 1014                 0.000000                  0   163975848       1.794205
# 1017                 0.000000                  0   163975848       3.519066
# 1021                 0.000000                  0   163975848     161.183840
# 1023                 0.000000                  0   163975848      14.894356
# 1036                 0.000000                  0   163975848    2587.667362
# 3005                 0.000000                  0   163975848     183.428234
# 3011                 0.000000                  0   163975848     261.144224
#
#               wifi_tx_packets      sum_power  wakelock_power_mah
# package_name
# 0                      204523  772953.355219        12934.568951
# 1006                        0      10.026885            0.000000
# 1013                        0   15110.994649          897.995183
# 1014                        0       1.794205            0.000000
# 1017                        0       3.519066            0.000000
# 1021                        0     161.183840            0.000000
# 1023                        0      14.894356            0.000000
# 1036                        0    2587.667362            0.000000
# 3005                        0     183.428234            0.000000
# 3011                        0     261.144224            0.000000

# %%
# power 사용량 Top N
package_df = package_df.sort_values(by='total_power', ascending=False) 
N = 20
package_df[['total_power','sum_power','usage_power_mah']].head(N).plot(figsize=(20,10), kind='bar')

# %%
# wifi packets 사용량 Top N
package_df = package_df.sort_values(by=['wifi_rx_packets', 'wifi_tx_packets'], ascending=False)
N = 20
package_df[['wifi_rx_packets','wifi_tx_packets']].head(N).plot(figsize=(20,10), kind='bar')

# %%
# mobile packets 사용량 Top N
package_df = package_df.sort_values(by=['mobile_rx_packets', 'mobile_tx_packets'], ascending=False)
N = 20
package_df[['mobile_rx_packets','mobile_tx_packets']].head(N).plot(figsize=(20,10), kind='bar')

# %%
# cpu power mah column으로 정렬
package_df = package_df.sort_values(by=['cpu_power_mah'], ascending=False)
N = 20
package_df[['cpu_power_mah']].head(N).plot(figsize=(20,10), kind='bar')

# %%
# min, max normalization 
def normalization(df, x, y):
    df_norm = (df - df.min()) / (df.max()-df.min()) 

    # range normalization [x, y] ex) [0, 100] 
    range = y - x
    normalized_df = (df_norm * range) + x
    return normalized_df

# %%
normalized_df = normalization(package_df, 0, 10)

# %%
N = 5
normalized_df.head(N).plot(figsize=(20,10), kind='bar')

# %%
N = 20
package_df[['wifi_rx_packets','wifi_tx_packets']].head(N).plot(figsize=(20,10), kind='bar')
